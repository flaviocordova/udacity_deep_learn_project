# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like translations.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with language and words, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print(text[:1000])
print(words[:80])
# Out:
#  anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic instituti
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term', 'is', 'still', 'used', 'in', 'a', 'pejorative', 'way', 'to', 'describe', 'any', 'act', 'that', 'used', 'violent', 'means', 'to', 'destroy', 'the', 'organization', 'of', 'society', 'it', 'has', 'also', 'been', 'taken', 'up', 'as', 'a', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'the', 'word', 'anarchism', 'is', 'derived', 'from', 'the', 'greek', 'without', 'archons', 'ruler', 'chief', 'king']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to covert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
from collections import Counter
import random

## Your code here
threshold = 1e-5
count_words = Counter(int_words)
total_count = len(int_words)
freqs = {word: count/total_count for word, count in count_words.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in count_words}
train_words = [word for word in int_words if p_drop[word] < random.random()]

print(len(int_words))
print(len(train_words))
# Out:
# 16680599
# 4627382

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    num_of_words = int(random.random() * window_size + 1)
    start_idx = max(0, idx - num_of_words)
    end_idx = min(len(words), idx + num_of_words + 1)
    result = words[start_idx:idx] + words[idx+1:end_idx]
    
    return result

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From Chris McCormick's blog, we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. This weight matrix is usually called the embedding matrix or embedding look-up table. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name="inputs")
    labels = tf.placeholder(tf.int32, [None, None], name="labels")

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of neurons in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using one-hot encoded vectors for our inputs. When you do the matrix multiplication of the one-hot vector with the embedding matrix, you end up selecting only one row out of the entire matrix:
#
# ![one-hot matrix multiplication](assets/matrix_mult_w_one_hot.png)
#
# You don't actually need to do the matrix multiplication, you just need to select the row in the embedding matrix that corresponds to the input word. Then, the embedding matrix becomes a lookup table, you're looking up a vector the size of the hidden layer that represents the input word.
#
# <img src="assets/word2vec_weight_matrix_lookup_table.png" width=500>
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform). This [TensorFlow tutorial](https://www.tensorflow.org/tutorials/word2vec) will help if you get stuck.

# %%
n_vocab = len(int_to_vocab)
n_embedding =  300
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: checkpoints: File exists

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 10
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/10 Iteration: 100 Avg. Training loss: 5.7141 0.6202 sec/batch
# Epoch 1/10 Iteration: 200 Avg. Training loss: 5.6882 0.5709 sec/batch
# Epoch 1/10 Iteration: 300 Avg. Training loss: 5.5711 0.6034 sec/batch
# Epoch 1/10 Iteration: 400 Avg. Training loss: 5.6738 0.5964 sec/batch
# Epoch 1/10 Iteration: 500 Avg. Training loss: 5.5890 0.6128 sec/batch
# Epoch 1/10 Iteration: 600 Avg. Training loss: 5.6010 0.5998 sec/batch
# Epoch 1/10 Iteration: 700 Avg. Training loss: 5.6300 0.6291 sec/batch
# Epoch 1/10 Iteration: 800 Avg. Training loss: 5.5822 0.6125 sec/batch
# Epoch 1/10 Iteration: 900 Avg. Training loss: 5.5203 0.6187 sec/batch
# Epoch 1/10 Iteration: 1000 Avg. Training loss: 5.4883 0.6086 sec/batch
# Nearest to be: inclinations, electrostatics, income, segal, metaphor, undemocratic, ames, adopted,
# Nearest to while: jokingly, impeachment, expounded, schemata, chairs, carcinoma, mysterium, lawsuits,
# Nearest to are: faure, saturn, criticism, dispelling, airtight, pozsony, gundestrup, robards,
# Nearest to to: block, begining, hawala, leopoldine, preservatives, birkhoff, bonewits, nuclides,
# Nearest to also: oul, crests, covert, doublet, grandsons, leftists, customised, ratzenberger,
# Nearest to s: tenochtitl, hn, scoundrel, clavell, referendum, phipps, musical, tuareg,
# Nearest to where: leveling, cardozo, footwork, fascio, rockets, ergo, feuding, fgm,
# Nearest to known: hu, tends, genealogy, icitap, wogan, hide, piety, exploiting,
# Nearest to award: battlecruiser, fervently, wakizashi, arrowhead, grudging, indefinitely, dukkha, reducible,
# Nearest to versions: adoptionism, colander, shia, hurrian, tarnishes, atle, jmp, landlines,
# Nearest to ocean: britain, kostas, cayenne, lb, unquestionably, aneurysm, frosty, arma,
# Nearest to question: grants, paradigmatic, mammals, bold, disinherited, outrageously, sopot, carr,
# Nearest to except: tenders, terribly, worms, czapski, whey, edmond, ascanius, thyme,
# Nearest to troops: parser, tariffs, garand, neophyte, bottomed, pnv, typos, macedonians,
# Nearest to taking: fulfill, vocals, merisi, nene, coots, overcame, attracts, aggadah,
# Nearest to joseph: infix, riflemen, tucked, justly, shopping, jbls, commitment, acres,
# Epoch 1/10 Iteration: 1100 Avg. Training loss: 5.5320 0.6767 sec/batch
# Epoch 1/10 Iteration: 1200 Avg. Training loss: 5.4387 0.6199 sec/batch
# Epoch 1/10 Iteration: 1300 Avg. Training loss: 5.4011 0.6205 sec/batch
# Epoch 1/10 Iteration: 1400 Avg. Training loss: 5.2882 0.5865 sec/batch
# Epoch 1/10 Iteration: 1500 Avg. Training loss: 5.2191 0.6164 sec/batch
# Epoch 1/10 Iteration: 1600 Avg. Training loss: 5.2143 0.5889 sec/batch
# Epoch 1/10 Iteration: 1700 Avg. Training loss: 5.1743 0.6566 sec/batch
# Epoch 1/10 Iteration: 1800 Avg. Training loss: 5.1244 0.5974 sec/batch
# Epoch 1/10 Iteration: 1900 Avg. Training loss: 5.0778 0.6165 sec/batch
# Epoch 1/10 Iteration: 2000 Avg. Training loss: 5.0534 0.5934 sec/batch
# Nearest to be: adopted, income, metaphor, inclinations, electrostatics, eat, segal, undemocratic,
# Nearest to while: jokingly, chairs, impeachment, lawsuits, buttons, steam, carcinoma, starring,
# Nearest to are: criticism, faure, saturn, completion, gundestrup, acceptance, airtight, bop,
# Nearest to to: block, begining, men, misleading, demonstrate, suggested, turns, bonewits,
# Nearest to also: covert, property, implemented, leftists, crests, cicero, bartolom, free,
# Nearest to s: tenochtitl, musical, european, evidence, referendum, phipps, scoundrel, hn,
# Nearest to where: leveling, busy, ergo, cardozo, quick, using, footwork, triangles,
# Nearest to known: tends, hu, hide, genealogy, remains, second, society, wogan,
# Nearest to award: battlecruiser, fervently, reducible, arrowhead, imperial, indefinitely, grudging, exhibit,
# Nearest to versions: adoptionism, colander, cairns, shia, rote, hurrian, jmp, humbled,
# Nearest to ocean: britain, kostas, lb, cayenne, time, unquestionably, presbyterian, microarchitecture,
# Nearest to question: grants, bold, considered, mammals, paradigmatic, disinherited, sopot, inspires,
# Nearest to except: terribly, tenders, worms, edmond, set, whey, czapski, artificial,
# Nearest to troops: parser, tariffs, garand, larry, bottomed, accord, example, prohibits,
# Nearest to taking: fulfill, nascent, vocals, seriously, occurs, sects, overcame, cosmology,
# Nearest to joseph: infix, tucked, justly, acres, shopping, faith, riflemen, garde,
# Epoch 1/10 Iteration: 2100 Avg. Training loss: 4.9939 0.6405 sec/batch
# Epoch 1/10 Iteration: 2200 Avg. Training loss: 4.9626 0.6002 sec/batch
# Epoch 1/10 Iteration: 2300 Avg. Training loss: 4.9529 0.6203 sec/batch
# Epoch 1/10 Iteration: 2400 Avg. Training loss: 4.9271 0.5884 sec/batch
# Epoch 1/10 Iteration: 2500 Avg. Training loss: 4.8831 0.6566 sec/batch
# Epoch 1/10 Iteration: 2600 Avg. Training loss: 4.8677 0.6385 sec/batch
# Epoch 1/10 Iteration: 2700 Avg. Training loss: 4.8755 0.6039 sec/batch
# Epoch 1/10 Iteration: 2800 Avg. Training loss: 4.8583 0.6286 sec/batch
# Epoch 1/10 Iteration: 2900 Avg. Training loss: 4.8493 0.6087 sec/batch
# Epoch 1/10 Iteration: 3000 Avg. Training loss: 4.8461 0.6162 sec/batch
# Nearest to be: adopted, metaphor, electrostatics, faded, inclinations, segal, undemocratic, eat,
# Nearest to while: jokingly, chairs, impeachment, buttons, expounded, schemata, lawsuits, carcinoma,
# Nearest to are: criticism, faure, saturn, genetics, bunyan, yeah, airtight, gundestrup,
# Nearest to to: block, interface, misleading, demonstrate, identities, birkhoff, deeply, preservatives,
# Nearest to also: covert, ownership, crests, leftists, bartolom, oul, ratzenberger, adhere,
# Nearest to s: tenochtitl, musical, turbojet, european, phipps, referendum, guilds, scoundrel,
# Nearest to where: leveling, footwork, cardozo, ergo, quick, busy, hamiltonian, triangles,
# Nearest to known: tends, genealogy, hu, icitap, exploiting, hide, remains, doesn,
# Nearest to award: battlecruiser, arrowhead, reducible, fervently, indefinitely, sinks, grudging, absent,
# Nearest to versions: adoptionism, shia, colander, rote, jmp, gaulois, sod, cairns,
# Nearest to ocean: britain, kostas, lb, cayenne, time, xiaoping, unquestionably, freelance,
# Nearest to question: grants, bold, mammals, considered, disinherited, paradigmatic, quake, sopot,
# Nearest to except: terribly, worms, tenders, edmond, transatlantic, useless, palestinian, pledging,
# Nearest to troops: parser, tariffs, garand, pensions, prohibits, repression, freeway, larry,
# Nearest to taking: fulfill, cosmology, attracts, overcame, sects, occurs, seriously, vocals,
# Nearest to joseph: infix, acres, tucked, commitment, shopping, justly, riflemen, garde,
# Epoch 1/10 Iteration: 3100 Avg. Training loss: 4.8282 0.6128 sec/batch
# Epoch 1/10 Iteration: 3200 Avg. Training loss: 4.8171 0.6103 sec/batch
# Epoch 1/10 Iteration: 3300 Avg. Training loss: 4.7899 0.6176 sec/batch
# Epoch 1/10 Iteration: 3400 Avg. Training loss: 4.7648 0.7012 sec/batch
# Epoch 1/10 Iteration: 3500 Avg. Training loss: 4.8053 0.6553 sec/batch
# Epoch 1/10 Iteration: 3600 Avg. Training loss: 4.7452 0.6142 sec/batch
# Epoch 1/10 Iteration: 3700 Avg. Training loss: 4.7545 0.6210 sec/batch
# Epoch 1/10 Iteration: 3800 Avg. Training loss: 4.7875 0.6135 sec/batch
# Epoch 1/10 Iteration: 3900 Avg. Training loss: 4.7472 0.6044 sec/batch
# Epoch 1/10 Iteration: 4000 Avg. Training loss: 4.6772 0.5994 sec/batch
# Nearest to be: inclinations, segal, faded, determinism, adopted, ames, metaphor, electrostatics,
# Nearest to while: jokingly, expounded, chairs, impeachment, schemata, congresses, lawsuits, exclusion,
# Nearest to are: criticism, faure, saturn, genetics, yeah, bunyan, kata, airtight,
# Nearest to to: block, demonstrate, interface, misleading, scruple, identities, undecided, preservatives,
# Nearest to also: covert, ratzenberger, oul, compelling, property, leftists, bartolom, crests,
# Nearest to s: tenochtitl, musical, turbojet, phipps, scoundrel, clavell, referendum, pekka,
# Nearest to where: leveling, footwork, cardozo, feuding, packets, hamiltonian, quick, rockets,
# Nearest to known: tends, genealogy, hu, icitap, doesn, jabal, remains, wogan,
# Nearest to award: arrowhead, grudging, herself, wakizashi, sinks, theorised, indefinitely, battlecruiser,
# Nearest to versions: adoptionism, shia, colander, rote, hurrian, jmp, sod, landlines,
# Nearest to ocean: britain, kostas, cayenne, lb, time, flamel, xiaoping, arma,
# Nearest to question: considered, mammals, disinherited, grants, bold, paradigmatic, quake, cardio,
# Nearest to except: terribly, worms, tenders, edmond, pledging, useless, transatlantic, palestinian,
# Nearest to troops: parser, tariffs, repression, bottomed, timaeus, teacher, accord, gop,
# Nearest to taking: cosmology, fulfill, attracts, tartarus, fdi, sects, safavid, australians,
# Nearest to joseph: acres, infix, tucked, shopping, riflemen, justly, commitment, biomass,
# Epoch 1/10 Iteration: 4100 Avg. Training loss: 4.7419 0.6383 sec/batch
# Epoch 1/10 Iteration: 4200 Avg. Training loss: 4.6891 0.6272 sec/batch
# Epoch 1/10 Iteration: 4300 Avg. Training loss: 4.6223 0.6093 sec/batch
# Epoch 1/10 Iteration: 4400 Avg. Training loss: 4.6700 0.6178 sec/batch
# Epoch 1/10 Iteration: 4500 Avg. Training loss: 4.6573 0.5898 sec/batch
# Epoch 1/10 Iteration: 4600 Avg. Training loss: 4.6630 0.6355 sec/batch
# Epoch 2/10 Iteration: 4700 Avg. Training loss: 4.6099 0.4288 sec/batch
# Epoch 2/10 Iteration: 4800 Avg. Training loss: 4.5453 0.7360 sec/batch
# Epoch 2/10 Iteration: 4900 Avg. Training loss: 4.5069 0.6637 sec/batch
# Epoch 2/10 Iteration: 5000 Avg. Training loss: 4.5213 0.6514 sec/batch
# Nearest to be: inclinations, segal, electrostatics, ames, determinism, marginal, ids, metaphor,
# Nearest to while: jokingly, expounded, schemata, congresses, chairs, impeachment, carcinoma, buttons,
# Nearest to are: faure, criticism, genetics, rasa, saturn, airtight, legs, pozsony,
# Nearest to to: undecided, block, interface, scruple, misleading, identities, preservatives, demonstrate,
# Nearest to also: oul, ratzenberger, covert, spalding, animistic, leftists, yoruba, bartolom,
# Nearest to s: tenochtitl, musical, turbojet, scoundrel, phipps, clavell, pekka, sexology,
# Nearest to where: footwork, leveling, cardozo, hamiltonian, licklider, quick, rockets, congresses,
# Nearest to known: tends, genealogy, upkeep, hu, jabal, remains, icitap, doesn,
# Nearest to award: arrowhead, wakizashi, grudging, sinks, fervently, theorised, nominations, herself,
# Nearest to versions: adoptionism, jmp, colander, rote, mac, hurrian, sod, shia,
# Nearest to ocean: britain, kostas, lb, cayenne, episodic, arma, detailing, xiaoping,
# Nearest to question: considered, mammals, paradigmatic, disinherited, grants, cardio, bold, quake,
# Nearest to except: terribly, worms, tenders, edmond, useless, thyme, pledging, whey,
# Nearest to troops: tariffs, parser, macedonians, repression, timaeus, accord, bottomed, pensions,
# Nearest to taking: cosmology, fulfill, tartarus, attracts, feedbacks, fdi, safavid, aggadah,
# Nearest to joseph: acres, tucked, infix, riflemen, shopping, commitment, biomass, ller,
# Epoch 2/10 Iteration: 5100 Avg. Training loss: 4.4662 0.6371 sec/batch
# Epoch 2/10 Iteration: 5200 Avg. Training loss: 4.4771 0.6247 sec/batch
# Epoch 2/10 Iteration: 5300 Avg. Training loss: 4.4281 0.7170 sec/batch
# Epoch 2/10 Iteration: 5400 Avg. Training loss: 4.5310 0.7348 sec/batch
# Epoch 2/10 Iteration: 5500 Avg. Training loss: 4.4441 0.7714 sec/batch
# Epoch 2/10 Iteration: 5600 Avg. Training loss: 4.4641 0.6924 sec/batch
# Epoch 2/10 Iteration: 5700 Avg. Training loss: 4.4542 0.8055 sec/batch
# Epoch 2/10 Iteration: 5800 Avg. Training loss: 4.3780 0.6743 sec/batch
# Epoch 2/10 Iteration: 5900 Avg. Training loss: 4.3893 0.6711 sec/batch
# Epoch 2/10 Iteration: 6000 Avg. Training loss: 4.3972 0.6984 sec/batch
# Nearest to be: electrostatics, inclinations, determinism, because, ames, adopted, intrinsically, ids,
# Nearest to while: jokingly, expounded, schemata, congresses, buttons, impeachment, chairs, lawsuits,
# Nearest to are: faure, criticism, pozsony, rasa, calcium, airtight, genetics, wavelengths,
# Nearest to to: block, interface, undecided, misleading, scruple, bonewits, disenfranchised, begining,
# Nearest to also: ratzenberger, oul, covert, nagorno, yoruba, animistic, lambeau, spalding,
# Nearest to s: tenochtitl, musical, turbojet, phipps, clavell, european, scoundrel, sexology,
# Nearest to where: footwork, leveling, cardozo, hamiltonian, licklider, psk, triangles, quick,
# Nearest to known: tends, genealogy, jabal, upkeep, icitap, remains, hu, underwrite,
# Nearest to award: arrowhead, nominated, wakizashi, nominations, fervently, herself, grudging, sinks,
# Nearest to versions: adoptionism, jmp, mac, colander, sod, hurrian, rote, cairns,
# Nearest to ocean: britain, lb, kostas, satellite, episodic, elevation, shortwave, cayenne,
# Nearest to question: considered, paradigmatic, mammals, disinherited, grants, bold, cardio, quake,
# Nearest to except: worms, terribly, tenders, whey, thyme, palestinian, useless, czapski,
# Nearest to troops: repression, tariffs, parser, timaeus, macedonians, bottomed, accord, rages,
# Nearest to taking: cosmology, fulfill, attracts, tartarus, fdi, australians, idiot, safavid,
# Nearest to joseph: riflemen, tucked, acres, infix, shopping, commitment, eyewitness, piazza,
# Epoch 2/10 Iteration: 6100 Avg. Training loss: 4.4261 0.6800 sec/batch
# Epoch 2/10 Iteration: 6200 Avg. Training loss: 4.3887 0.6841 sec/batch
# Epoch 2/10 Iteration: 6300 Avg. Training loss: 4.4043 0.6127 sec/batch
# Epoch 2/10 Iteration: 6400 Avg. Training loss: 4.3811 0.6700 sec/batch
# Epoch 2/10 Iteration: 6500 Avg. Training loss: 4.3746 0.7599 sec/batch
# Epoch 2/10 Iteration: 6600 Avg. Training loss: 4.4529 0.6550 sec/batch
# Epoch 2/10 Iteration: 6700 Avg. Training loss: 4.3389 0.6295 sec/batch
# Epoch 2/10 Iteration: 6800 Avg. Training loss: 4.3543 0.6473 sec/batch
# Epoch 2/10 Iteration: 6900 Avg. Training loss: 4.3853 0.6443 sec/batch
# Epoch 2/10 Iteration: 7000 Avg. Training loss: 4.3754 0.6167 sec/batch
# Nearest to be: electrostatics, intrinsically, because, inclinations, determinism, adopted, ids, ames,
# Nearest to while: jokingly, expounded, schemata, congresses, buttons, spurt, lawsuits, impeachment,
# Nearest to are: faure, criticism, pozsony, airtight, rasa, genetics, calcium, wavelengths,
# Nearest to to: undecided, block, misleading, disenfranchised, skilling, interface, bonewits, birkhoff,
# Nearest to also: ratzenberger, oul, nagorno, spalding, fillers, animistic, toby, lambeau,
# Nearest to s: tenochtitl, musical, turbojet, clavell, sexology, phipps, entitled, fiorentina,
# Nearest to where: footwork, leveling, cardozo, sum, licklider, hamiltonian, psk, friction,
# Nearest to known: tends, genealogy, jabal, remains, icitap, upkeep, underwrite, hu,
# Nearest to award: arrowhead, nominated, nominations, herself, wakizashi, grudging, fervently, awards,
# Nearest to versions: adoptionism, jmp, mac, rote, floppy, sod, colander, cairns,
# Nearest to ocean: britain, satellite, elevation, lb, shortwave, kostas, cayenne, arma,
# Nearest to question: considered, paradigmatic, bold, disinherited, grants, mammals, cardio, sopot,
# Nearest to except: worms, terribly, tenders, whey, thyme, kono, palestinian, openings,
# Nearest to troops: repression, tariffs, rages, macedonians, timaeus, civilian, parser, forces,
# Nearest to taking: cosmology, fulfill, attracts, fdi, finalize, nascent, dyslexia, amniocentesis,
# Nearest to joseph: riflemen, acres, tucked, piazza, infix, lakeland, commitment, eyewitness,
# Epoch 2/10 Iteration: 7100 Avg. Training loss: 4.3477 0.6810 sec/batch
# Epoch 2/10 Iteration: 7200 Avg. Training loss: 4.3791 0.6614 sec/batch
# Epoch 2/10 Iteration: 7300 Avg. Training loss: 4.3219 0.6589 sec/batch
# Epoch 2/10 Iteration: 7400 Avg. Training loss: 4.3130 0.5948 sec/batch
# Epoch 2/10 Iteration: 7500 Avg. Training loss: 4.3779 0.6492 sec/batch
# Epoch 2/10 Iteration: 7600 Avg. Training loss: 4.3434 0.6238 sec/batch
# Epoch 2/10 Iteration: 7700 Avg. Training loss: 4.3373 0.6297 sec/batch
# Epoch 2/10 Iteration: 7800 Avg. Training loss: 4.3427 0.6359 sec/batch
# Epoch 2/10 Iteration: 7900 Avg. Training loss: 4.3091 0.6664 sec/batch
# Epoch 2/10 Iteration: 8000 Avg. Training loss: 4.3075 0.7017 sec/batch
# Nearest to be: adopted, ids, because, electrostatics, intrinsically, ames, intervenes, biogeography,
# Nearest to while: jokingly, expounded, congresses, schemata, spurt, buttons, impeachment, aqualung,
# Nearest to are: faure, criticism, airtight, pozsony, rasa, genetics, calcium, dessert,
# Nearest to to: undecided, misleading, disenfranchised, skilling, scruple, begining, disgruntled, bonewits,
# Nearest to also: ratzenberger, oul, relaunched, nagorno, animistic, spalding, leftists, toby,
# Nearest to s: tenochtitl, turbojet, clavell, sexology, musical, entitled, aged, inhabits,
# Nearest to where: footwork, licklider, cardozo, psk, sum, leveling, trivial, zf,
# Nearest to known: tends, genealogy, jabal, remains, icitap, upkeep, underwrite, charis,
# Nearest to award: arrowhead, nominated, nominations, herself, grudging, fervently, awards, wakizashi,
# Nearest to versions: adoptionism, mac, nt, jmp, unix, sod, landlines, colander,
# Nearest to ocean: britain, elevation, sea, satellite, shortwave, lb, kostas, cayenne,
# Nearest to question: considered, paradigmatic, bold, disinherited, grants, subsisting, verify, metrics,
# Nearest to except: worms, terribly, tenders, thyme, whey, palestinian, ascanius, fatou,
# Nearest to troops: repression, tariffs, rages, civilian, army, forces, timaeus, accord,
# Nearest to taking: cosmology, fulfill, attracts, fdi, tartarus, dyslexia, alphege, australians,
# Nearest to joseph: riflemen, acres, tucked, salzburg, eyewitness, infix, lakeland, commitment,
# Epoch 2/10 Iteration: 8100 Avg. Training loss: 4.3052 0.6624 sec/batch
# Epoch 2/10 Iteration: 8200 Avg. Training loss: 4.2768 0.7164 sec/batch
# Epoch 2/10 Iteration: 8300 Avg. Training loss: 4.3495 0.6818 sec/batch
# Epoch 2/10 Iteration: 8400 Avg. Training loss: 4.3472 0.7022 sec/batch
# Epoch 2/10 Iteration: 8500 Avg. Training loss: 4.3455 0.6341 sec/batch
# Epoch 2/10 Iteration: 8600 Avg. Training loss: 4.2446 0.6351 sec/batch
# Epoch 2/10 Iteration: 8700 Avg. Training loss: 4.2306 0.6679 sec/batch
# Epoch 2/10 Iteration: 8800 Avg. Training loss: 4.2820 0.6408 sec/batch
# Epoch 2/10 Iteration: 8900 Avg. Training loss: 4.1843 0.6526 sec/batch
# Epoch 2/10 Iteration: 9000 Avg. Training loss: 4.2661 0.6349 sec/batch
# Nearest to be: intervenes, intrinsically, if, inclinations, ids, segal, faded, electrostatics,
# Nearest to while: jokingly, expounded, spurt, congresses, schemata, impeachment, exclusion, hurrian,
# Nearest to are: faure, airtight, criticism, pozsony, rasa, kata, smarta, genetics,
# Nearest to to: undecided, disenfranchised, skilling, misleading, block, finiteness, interface, preservatives,
# Nearest to also: ratzenberger, oul, spalding, animistic, leftists, fillers, nagorno, relaunched,
# Nearest to s: tenochtitl, turbojet, musical, sexology, aged, entitled, clavell, fiorentina,
# Nearest to where: footwork, licklider, cardozo, psk, zf, woolly, apiece, leveling,
# Nearest to known: genealogy, tends, jabal, upkeep, remains, icitap, crevasses, charis,
# Nearest to award: nominated, nominations, arrowhead, awards, herself, grudging, fervently, wakizashi,
# Nearest to versions: nt, adoptionism, mac, jmp, sod, colander, mauser, unix,
# Nearest to ocean: britain, satellite, shortwave, elevation, sea, kostas, lb, rico,
# Nearest to question: considered, paradigmatic, bold, grants, inspires, subsisting, mlas, outrageously,
# Nearest to except: worms, tenders, terribly, thyme, coconut, ascanius, czapski, pledging,
# Nearest to troops: repression, civilian, forces, tariffs, army, rages, sides, seto,
# Nearest to taking: cosmology, fdi, fulfill, attracts, dyslexia, australians, tartarus, alphege,
# Nearest to joseph: riflemen, infix, salzburg, lakeland, gunshot, eyewitness, biomass, latterly,
# Epoch 2/10 Iteration: 9100 Avg. Training loss: 4.2954 0.6721 sec/batch
# Epoch 2/10 Iteration: 9200 Avg. Training loss: 4.2543 0.6286 sec/batch
# Epoch 3/10 Iteration: 9300 Avg. Training loss: 4.3075 0.3144 sec/batch
# Epoch 3/10 Iteration: 9400 Avg. Training loss: 4.2297 0.6573 sec/batch
# Epoch 3/10 Iteration: 9500 Avg. Training loss: 4.1668 0.9344 sec/batch
# Epoch 3/10 Iteration: 10500 Avg. Training loss: 4.1244 1.3052 sec/batch
# Epoch 3/10 Iteration: 11400 Avg. Training loss: 4.0870 0.7587 sec/batch
# Epoch 3/10 Iteration: 11500 Avg. Training loss: 4.0878 0.5986 sec/batch
# Epoch 3/10 Iteration: 11600 Avg. Training loss: 4.1070 0.6273 sec/batch
# Epoch 3/10 Iteration: 11700 Avg. Training loss: 4.1415 0.6326 sec/batch
# Epoch 3/10 Iteration: 11800 Avg. Training loss: 4.0804 0.5942 sec/batch
# Epoch 3/10 Iteration: 11900 Avg. Training loss: 4.0889 0.5923 sec/batch
# Epoch 3/10 Iteration: 12000 Avg. Training loss: 4.1103 0.5921 sec/batch
# Nearest to be: intervenes, because, electrostatics, intrinsically, faded, provability, superintendence, wherever,
# Nearest to while: jokingly, disbelief, schemata, spurt, actuality, congresses, chairs, expounded,
# Nearest to are: airtight, smarta, faure, rasa, pozsony, kata, criticism, dessert,
# Nearest to to: disenfranchised, misleading, undecided, skilling, philosophicus, traitors, labial, replaced,
# Nearest to also: ratzenberger, spalding, oul, venues, relaunched, toby, wco, nagorno,
# Nearest to s: tenochtitl, turbojet, clavell, entitled, dubious, imagination, fiorentina, setting,
# Nearest to where: footwork, zf, sum, woolly, psk, licklider, carotenoids, leveling,
# Nearest to known: genealogy, tends, jabal, upkeep, remains, housemates, organelles, hamadan,
# Nearest to award: nominated, nominations, awards, arrowhead, herself, fervently, battlecruiser, wakizashi,
# Nearest to versions: adoptionism, nt, cairns, mauser, jmp, landlines, sod, divination,
# Nearest to ocean: britain, shortwave, intelsat, lb, kostas, satellite, sea, rico,
# Nearest to question: paradigmatic, considered, bold, grants, metrics, harmonies, outrageously, subsisting,
# Nearest to except: worms, terribly, tenders, thyme, coconut, whey, openings, ascanius,
# Nearest to troops: repression, army, civilian, forces, ironclad, rages, cargo, tariffs,
# Nearest to taking: cosmology, fdi, attracts, alphege, fulfill, amniocentesis, nascent, invariant,
# Nearest to joseph: riflemen, infix, eyewitness, salzburg, ller, biomass, mackintosh, syndicalist,
# Epoch 3/10 Iteration: 12100 Avg. Training loss: 4.1377 0.6247 sec/batch
# Epoch 3/10 Iteration: 12200 Avg. Training loss: 4.1208 0.6077 sec/batch
# Epoch 3/10 Iteration: 12300 Avg. Training loss: 4.1377 0.7528 sec/batch
# Epoch 3/10 Iteration: 12400 Avg. Training loss: 4.1162 0.6521 sec/batch
# Epoch 3/10 Iteration: 12500 Avg. Training loss: 4.1004 0.6196 sec/batch
# Epoch 3/10 Iteration: 12600 Avg. Training loss: 4.0369 0.5893 sec/batch
# Epoch 3/10 Iteration: 12700 Avg. Training loss: 4.1368 0.6983 sec/batch
# Epoch 3/10 Iteration: 12800 Avg. Training loss: 4.0960 0.7213 sec/batch
# Epoch 3/10 Iteration: 12900 Avg. Training loss: 4.1624 0.7138 sec/batch
# Epoch 3/10 Iteration: 13000 Avg. Training loss: 4.1626 0.7229 sec/batch
# Nearest to be: intervenes, because, faded, provability, undemocratic, inclinations, intrinsically, superintendence,
# Nearest to while: jokingly, disbelief, expounded, chairs, actuality, spurt, exclusion, congresses,
# Nearest to are: faure, airtight, smarta, kata, pozsony, rasa, below, criticism,
# Nearest to to: disenfranchised, traitors, undecided, misleading, skilling, leopoldine, bring, replaced,
# Nearest to also: ratzenberger, spalding, toby, relaunched, venues, muslim, oul, carillon,
# Nearest to s: tenochtitl, referendum, dubious, entitled, turbojet, clavell, imagination, phipps,
# Nearest to where: footwork, woolly, licklider, zf, cardozo, sum, carotenoids, mortgaged,
# Nearest to known: genealogy, jabal, tends, upkeep, housemates, remains, hamadan, khayy,
# Nearest to award: awards, nominated, nominations, arrowhead, emmy, best, fervently, herself,
# Nearest to versions: nt, adoptionism, cairns, jmp, mauser, sod, landlines, atle,
# Nearest to ocean: britain, shortwave, intelsat, satellite, kostas, neva, lb, rico,
# Nearest to question: paradigmatic, considered, bold, grants, subsisting, mlas, acceptable, harmonies,
# Nearest to except: worms, terribly, thyme, tenders, coconut, juicy, earthbound, possessive,
# Nearest to troops: repression, civilian, army, rages, forces, seto, ironclad, cargo,
# Nearest to taking: cosmology, fdi, attracts, alphege, fulfill, idiot, nascent, invariant,
# Nearest to joseph: riflemen, salzburg, infix, lakeland, faith, eyewitness, gunshot, strasbourg,
# Epoch 3/10 Iteration: 13100 Avg. Training loss: 4.1423 0.6936 sec/batch
# Epoch 3/10 Iteration: 13200 Avg. Training loss: 4.1032 0.7259 sec/batch
# Epoch 3/10 Iteration: 13300 Avg. Training loss: 4.0536 0.7046 sec/batch
# Epoch 3/10 Iteration: 13400 Avg. Training loss: 4.0962 0.7177 sec/batch
# Epoch 3/10 Iteration: 13500 Avg. Training loss: 3.9911 0.7205 sec/batch
# Epoch 3/10 Iteration: 13600 Avg. Training loss: 4.1178 0.8261 sec/batch
# Epoch 3/10 Iteration: 13700 Avg. Training loss: 4.0692 0.7417 sec/batch
# Epoch 3/10 Iteration: 13800 Avg. Training loss: 4.0951 0.7194 sec/batch
# Epoch 4/10 Iteration: 13900 Avg. Training loss: 4.1282 0.1672 sec/batch
# Epoch 4/10 Iteration: 14000 Avg. Training loss: 4.0455 0.8678 sec/batch
# Nearest to be: intervenes, because, faded, provability, superintendence, inclinations, marginal, ankles,
# Nearest to while: jokingly, disbelief, spurt, actuality, exclusion, expounded, schemata, chairs,
# Nearest to are: airtight, faure, kata, below, smarta, rasa, pozsony, distinguishing,
# Nearest to to: misleading, disenfranchised, bring, traitors, labial, replaced, skilling, undecided,
# Nearest to also: ratzenberger, spalding, relaunched, matchbox, venues, muslim, wco, toby,
# Nearest to s: tenochtitl, turbojet, dubious, referendum, sexology, aged, maradona, entitled,
# Nearest to where: footwork, woolly, zf, mortgaged, licklider, ellipsoids, sum, blocked,
# Nearest to known: genealogy, tends, upkeep, crevasses, housemates, second, jabal, remains,
# Nearest to award: nominations, nominated, awards, arrowhead, fervently, best, emmy, chicagoans,
# Nearest to versions: nt, adoptionism, mac, jmp, mauser, landlines, sod, cairns,
# Nearest to ocean: shortwave, intelsat, britain, satellite, sea, neva, kostas, lb,
# Nearest to question: paradigmatic, considered, grants, subsisting, bold, mlas, harmonies, acceptable,
# Nearest to except: worms, thyme, terribly, tenders, coconut, juicy, earthbound, whey,
# Nearest to troops: army, ironclad, rages, repression, civilian, seto, forces, garand,
# Nearest to taking: cosmology, fdi, attracts, alphege, nene, amniocentesis, invariant, idiot,
# Nearest to joseph: salzburg, riflemen, infix, strasbourg, syndicalist, lakeland, gunshot, faith,
# Epoch 4/10 Iteration: 14100 Avg. Training loss: 4.0086 0.7634 sec/batch
# Epoch 4/10 Iteration: 14200 Avg. Training loss: 4.0157 0.7837 sec/batch
# Epoch 4/10 Iteration: 14300 Avg. Training loss: 4.0309 1.0013 sec/batch
# Epoch 4/10 Iteration: 14400 Avg. Training loss: 3.9744 0.9966 sec/batch
# Epoch 4/10 Iteration: 14500 Avg. Training loss: 4.0092 0.8663 sec/batch
# Epoch 4/10 Iteration: 14600 Avg. Training loss: 3.9644 0.8181 sec/batch
# Epoch 4/10 Iteration: 14700 Avg. Training loss: 3.9962 0.7775 sec/batch
# Epoch 4/10 Iteration: 14800 Avg. Training loss: 4.0374 0.7549 sec/batch
# Epoch 4/10 Iteration: 14900 Avg. Training loss: 4.0565 0.7738 sec/batch
# Epoch 4/10 Iteration: 15000 Avg. Training loss: 3.9282 0.7239 sec/batch
# Nearest to be: intervenes, because, superintendence, faded, inclinations, provability, marginal, intrinsically,
# Nearest to while: jokingly, spurt, actuality, disbelief, diane, exclusion, chairs, buttons,
# Nearest to are: airtight, kata, below, faure, smarta, rasa, pozsony, taxa,
# Nearest to to: replaced, bring, traitors, which, misleading, unlocks, begining, labial,
# Nearest to also: muslim, ratzenberger, spalding, relaunched, venues, toby, matchbox, oul,
# Nearest to s: tenochtitl, turbojet, dubious, grossing, entitled, maradona, phipps, redeem,
# Nearest to where: footwork, zf, sum, woolly, ellipsoids, trivial, hamiltonian, licklider,
# Nearest to known: genealogy, jabal, upkeep, remains, tends, housemates, crevasses, second,
# Nearest to award: awards, nominated, nominations, arrowhead, best, fervently, chicagoans, emmy,
# Nearest to versions: nt, jmp, adoptionism, mac, mauser, landlines, cairns, divination,
# Nearest to ocean: shortwave, intelsat, britain, satellite, sea, neva, kostas, conglomerates,
# Nearest to question: paradigmatic, considered, grants, bold, mlas, subsisting, acceptable, stabs,
# Nearest to except: worms, thyme, terribly, tenders, coconut, openings, possessive, juicy,
# Nearest to troops: army, forces, ironclad, civilian, rages, repression, seto, garand,
# Nearest to taking: cosmology, attracts, alphege, fdi, jezebel, wondering, amniocentesis, idiot,
# Nearest to joseph: infix, riflemen, faith, salzburg, gunshot, syndicalist, eyewitness, biomass,
# Epoch 4/10 Iteration: 15100 Avg. Training loss: 3.9614 0.7896 sec/batch
# Epoch 4/10 Iteration: 15200 Avg. Training loss: 3.9803 0.7356 sec/batch
# Epoch 4/10 Iteration: 15300 Avg. Training loss: 3.9350 0.7678 sec/batch
# Epoch 4/10 Iteration: 15400 Avg. Training loss: 3.9715 0.7586 sec/batch
# Epoch 4/10 Iteration: 15500 Avg. Training loss: 3.9815 0.7725 sec/batch
# Epoch 4/10 Iteration: 15600 Avg. Training loss: 3.9964 1.0034 sec/batch
# Epoch 4/10 Iteration: 15700 Avg. Training loss: 3.9929 2.1161 sec/batch
# Epoch 4/10 Iteration: 15800 Avg. Training loss: 4.0276 1.5157 sec/batch
# Epoch 4/10 Iteration: 15900 Avg. Training loss: 4.0073 1.3292 sec/batch
# Epoch 4/10 Iteration: 16000 Avg. Training loss: 3.9791 1.2311 sec/batch
# Nearest to be: intervenes, because, electrostatics, marginal, provability, intrinsically, inclinations, superintendence,
# Nearest to while: jokingly, actuality, spurt, chairs, disbelief, exclusion, congresses, diane,
# Nearest to are: airtight, faure, kata, below, smarta, pozsony, rasa, distinguishing,
# Nearest to to: misleading, philosophicus, bring, which, begining, labial, finiteness, nuclides,
# Nearest to also: ratzenberger, toby, relaunched, spalding, muslim, venues, dysfunctional, in,
# Nearest to s: tenochtitl, entitled, turbojet, imagination, redeem, dubious, oli, maradona,
# Nearest to where: footwork, zf, woolly, sum, ellipsoids, licklider, trivial, using,
# Nearest to known: genealogy, jabal, upkeep, remains, organelles, housemates, crevasses, second,
# Nearest to award: nominated, awards, nominations, arrowhead, fervently, emmy, chicagoans, best,
# Nearest to versions: nt, adoptionism, cairns, mauser, jmp, landlines, divination, directx,
# Nearest to ocean: shortwave, britain, intelsat, satellite, sea, kostas, neva, conglomerates,
# Nearest to question: paradigmatic, considered, bold, grants, mlas, subsisting, constrained, metrics,
# Nearest to except: worms, thyme, terribly, juicy, openings, tenders, earthbound, possessive,
# Nearest to troops: ironclad, army, forces, civilian, seto, rages, repression, garand,
# Nearest to taking: cosmology, fdi, invariant, amniocentesis, alphege, attracts, occurs, idiot,
# Nearest to joseph: faith, riflemen, salzburg, infix, gunshot, syndicalist, eyewitness, biomass,
# Epoch 4/10 Iteration: 16100 Avg. Training loss: 3.9564 0.9441 sec/batch
# Epoch 4/10 Iteration: 16200 Avg. Training loss: 4.0216 0.6697 sec/batch
# Epoch 4/10 Iteration: 16300 Avg. Training loss: 3.9938 0.6230 sec/batch
# Epoch 4/10 Iteration: 16400 Avg. Training loss: 3.9672 0.6293 sec/batch
# Epoch 4/10 Iteration: 16500 Avg. Training loss: 4.0034 0.5938 sec/batch
# Epoch 4/10 Iteration: 16600 Avg. Training loss: 4.0158 0.5816 sec/batch
# Epoch 4/10 Iteration: 16700 Avg. Training loss: 4.0123 0.6398 sec/batch
# Epoch 4/10 Iteration: 16800 Avg. Training loss: 3.9848 0.5916 sec/batch
# Epoch 4/10 Iteration: 16900 Avg. Training loss: 3.9933 0.5896 sec/batch
# Epoch 4/10 Iteration: 17000 Avg. Training loss: 3.9878 0.6008 sec/batch
# Nearest to be: because, intervenes, provability, inclinations, superintendence, marginal, electrostatics, leaguers,
# Nearest to while: jokingly, disbelief, actuality, spurt, diane, chairs, fleetwood, congresses,
# Nearest to are: smarta, faure, airtight, kata, below, distinguishing, pozsony, rasa,
# Nearest to to: disenfranchised, misleading, replaced, which, undecided, bring, philosophicus, begining,
# Nearest to also: ratzenberger, toby, muslim, relaunched, spalding, matchbox, venues, dysfunctional,
# Nearest to s: tenochtitl, entitled, redeem, turbojet, dubious, referendum, oli, maradona,
# Nearest to where: footwork, woolly, zf, ellipsoids, licklider, mortgaged, using, carotenoids,
# Nearest to known: genealogy, upkeep, jabal, housemates, remains, second, hamadan, king,
# Nearest to award: awards, nominated, nominations, arrowhead, emmy, best, fervently, chicagoans,
# Nearest to versions: nt, divination, mauser, landlines, cairns, jmp, directx, adoptionism,
# Nearest to ocean: britain, shortwave, intelsat, kostas, neva, satellite, conglomerates, shoal,
# Nearest to question: considered, paradigmatic, bold, grants, subsisting, mlas, acceptable, commenting,
# Nearest to except: worms, thyme, juicy, tenders, terribly, synoptic, possessive, earthbound,
# Nearest to troops: army, ironclad, forces, civilian, repression, rages, seto, macedonians,
# Nearest to taking: cosmology, fdi, alphege, bribes, jezebel, amniocentesis, finalize, attracts,
# Nearest to joseph: riflemen, salzburg, faith, syndicalist, infix, eyewitness, misches, gunshot,
# Epoch 4/10 Iteration: 17100 Avg. Training loss: 3.9571 0.6191 sec/batch
# Epoch 4/10 Iteration: 17200 Avg. Training loss: 3.9177 0.6300 sec/batch
# Epoch 4/10 Iteration: 17300 Avg. Training loss: 3.9553 0.6346 sec/batch
# Epoch 4/10 Iteration: 17400 Avg. Training loss: 4.0253 0.6864 sec/batch
# Epoch 4/10 Iteration: 17500 Avg. Training loss: 4.0066 0.8943 sec/batch
# Epoch 4/10 Iteration: 17600 Avg. Training loss: 4.0594 0.6038 sec/batch
# Epoch 4/10 Iteration: 17700 Avg. Training loss: 4.0323 0.5928 sec/batch
# Epoch 4/10 Iteration: 17800 Avg. Training loss: 3.9719 0.6954 sec/batch
# Epoch 4/10 Iteration: 17900 Avg. Training loss: 3.9474 0.6189 sec/batch
# Epoch 4/10 Iteration: 18000 Avg. Training loss: 3.9521 0.6980 sec/batch
# Nearest to be: provability, because, intervenes, inclinations, superintendence, wherever, marginal, ankles,
# Nearest to while: jokingly, actuality, disbelief, spurt, chairs, diane, fleetwood, exclusion,
# Nearest to are: kata, below, airtight, faure, smarta, distinguishing, is, pozsony,
# Nearest to to: disenfranchised, misleading, traitors, unlocks, which, labial, leopoldine, speer,
# Nearest to also: ratzenberger, relaunched, toby, matchbox, in, spalding, dysfunctional, nonempty,
# Nearest to s: tenochtitl, entitled, turbojet, oli, maradona, grossing, fiorentina, quijote,
# Nearest to where: footwork, woolly, zf, ellipsoids, mortgaged, carotenoids, licklider, trivial,
# Nearest to known: upkeep, genealogy, housemates, jabal, second, twists, king, underwrite,
# Nearest to award: awards, nominations, nominated, best, arrowhead, chicagoans, emmy, fervently,
# Nearest to versions: nt, landlines, cairns, mac, mauser, jmp, divination, sod,
# Nearest to ocean: britain, shortwave, intelsat, kostas, neva, satellite, sea, shoal,
# Nearest to question: considered, paradigmatic, subsisting, bold, grants, mlas, esti, acceptable,
# Nearest to except: worms, thyme, juicy, earthbound, terribly, possessive, coconut, tenders,
# Nearest to troops: army, ironclad, repression, civilian, forces, rages, seto, stavropol,
# Nearest to taking: cosmology, fdi, alphege, jezebel, bribes, amniocentesis, invariant, attracts,
# Nearest to joseph: riflemen, gunshot, salzburg, misches, faith, infix, eyewitness, mortar,
# Epoch 4/10 Iteration: 18100 Avg. Training loss: 3.9167 0.6196 sec/batch
# Epoch 4/10 Iteration: 18200 Avg. Training loss: 3.9607 0.6095 sec/batch
# Epoch 4/10 Iteration: 18300 Avg. Training loss: 3.9819 0.5982 sec/batch
# Epoch 4/10 Iteration: 18400 Avg. Training loss: 3.9473 0.5923 sec/batch
# Epoch 4/10 Iteration: 18500 Avg. Training loss: 4.0087 0.6076 sec/batch
# Epoch 5/10 Iteration: 18600 Avg. Training loss: 3.9751 0.5791 sec/batch
# Epoch 5/10 Iteration: 18700 Avg. Training loss: 3.9172 0.6097 sec/batch
# Epoch 5/10 Iteration: 18800 Avg. Training loss: 3.9120 0.6315 sec/batch
# Epoch 5/10 Iteration: 18900 Avg. Training loss: 3.9170 0.6055 sec/batch
# Epoch 5/10 Iteration: 19000 Avg. Training loss: 3.9016 0.6110 sec/batch
# Nearest to be: because, provability, intervenes, superintendence, inclinations, wherever, marginal, faded,
# Nearest to while: jokingly, spurt, disbelief, actuality, fleetwood, diane, chairs, hurrian,
# Nearest to are: kata, smarta, below, faure, distinguishing, rrebro, airtight, pozsony,
# Nearest to to: traitors, labial, misleading, which, disenfranchised, undecided, speer, over,
# Nearest to also: relaunched, matchbox, ratzenberger, in, muslim, spalding, toby, oul,
# Nearest to s: tenochtitl, maradona, entitled, imagination, oli, turbojet, grossing, aged,
# Nearest to where: footwork, woolly, ellipsoids, zf, mortgaged, carotenoids, ket, uf,
# Nearest to known: upkeep, genealogy, housemates, jabal, twists, underwrite, second, established,
# Nearest to award: awards, nominations, nominated, best, academy, arrowhead, chicagoans, emmy,
# Nearest to versions: nt, mac, landlines, directx, mauser, jmp, divination, cairns,
# Nearest to ocean: shortwave, intelsat, britain, satellite, shoal, kostas, neva, conglomerates,
# Nearest to question: considered, paradigmatic, subsisting, grants, mlas, bold, acceptable, esti,
# Nearest to except: worms, thyme, juicy, earthbound, terribly, possessive, oils, tenders,
# Nearest to troops: army, ironclad, stavropol, civilian, rages, garand, forces, seto,
# Nearest to taking: cosmology, fdi, alphege, bribes, amniocentesis, jezebel, finalize, attracts,
# Nearest to joseph: riflemen, gunshot, salzburg, faith, misches, infix, mortar, eyewitness,
# Epoch 5/10 Iteration: 19100 Avg. Training loss: 3.9033 0.6553 sec/batch
# Epoch 5/10 Iteration: 19200 Avg. Training loss: 3.8482 0.5921 sec/batch
# Epoch 5/10 Iteration: 19300 Avg. Training loss: 3.9139 0.6076 sec/batch
# Epoch 5/10 Iteration: 19400 Avg. Training loss: 3.9621 0.5892 sec/batch
# Epoch 5/10 Iteration: 19500 Avg. Training loss: 3.9097 0.6248 sec/batch
# Epoch 5/10 Iteration: 19600 Avg. Training loss: 3.8977 0.6285 sec/batch
# Epoch 5/10 Iteration: 19700 Avg. Training loss: 3.8450 0.5990 sec/batch
# Epoch 5/10 Iteration: 19800 Avg. Training loss: 3.8754 0.6620 sec/batch
# Epoch 5/10 Iteration: 19900 Avg. Training loss: 3.8114 0.6399 sec/batch
# Epoch 5/10 Iteration: 20000 Avg. Training loss: 3.8874 0.6001 sec/batch
# Nearest to be: because, provability, wherever, intervenes, if, superintendence, pagerank, additivity,
# Nearest to while: jokingly, spurt, actuality, fleetwood, congresses, disbelief, diane, exclusion,
# Nearest to are: kata, faure, smarta, below, taxa, airtight, pozsony, racine,
# Nearest to to: which, misleading, labial, undecided, a, sanjo, finiteness, over,
# Nearest to also: muslim, in, ratzenberger, nonempty, matchbox, relaunched, nagorno, spalding,
# Nearest to s: tenochtitl, maradona, entitled, six, imagination, dubious, fiorentina, redeem,
# Nearest to where: ellipsoids, footwork, woolly, zf, uf, carotenoids, mortgaged, ket,
# Nearest to known: genealogy, upkeep, jabal, underwrite, twists, established, second, housemates,
# Nearest to award: awards, nominations, nominated, best, arrowhead, academy, chicagoans, emmy,
# Nearest to versions: nt, cairns, divination, landlines, shia, adoptionism, sod, jmp,
# Nearest to ocean: britain, shortwave, intelsat, kostas, satellite, shoal, rico, time,
# Nearest to question: considered, paradigmatic, grants, subsisting, mlas, bold, esti, constrained,
# Nearest to except: worms, thyme, juicy, synoptic, laterals, earthbound, terribly, oils,
# Nearest to troops: army, ironclad, forces, rages, civilian, stavropol, garand, repression,
# Nearest to taking: cosmology, jezebel, alphege, amniocentesis, bribes, fdi, invariant, finalize,
# Nearest to joseph: infix, gunshot, faith, mortar, riflemen, salzburg, misches, eyewitness,
# Epoch 5/10 Iteration: 20100 Avg. Training loss: 3.9292 0.6268 sec/batch
# Epoch 5/10 Iteration: 20200 Avg. Training loss: 3.9072 0.6369 sec/batch
# Epoch 5/10 Iteration: 20300 Avg. Training loss: 3.8844 0.6159 sec/batch
# Epoch 5/10 Iteration: 20400 Avg. Training loss: 3.8876 0.6857 sec/batch
# Epoch 5/10 Iteration: 20500 Avg. Training loss: 3.9720 0.6300 sec/batch
# Epoch 5/10 Iteration: 20600 Avg. Training loss: 3.8541 0.6126 sec/batch
# Epoch 5/10 Iteration: 20700 Avg. Training loss: 3.9126 1.1077 sec/batch
# Epoch 5/10 Iteration: 20800 Avg. Training loss: 3.9014 0.7105 sec/batch
# Epoch 5/10 Iteration: 20900 Avg. Training loss: 3.9190 0.6330 sec/batch
# Epoch 5/10 Iteration: 21000 Avg. Training loss: 3.9081 0.6500 sec/batch
# Nearest to be: because, provability, intervenes, superintendence, wherever, electrostatics, gamblers, dismal,
# Nearest to while: jokingly, spurt, actuality, disbelief, short, fleetwood, diane, chairs,
# Nearest to are: kata, faure, smarta, other, below, airtight, pozsony, yttrium,
# Nearest to to: which, labial, sanjo, nuclides, misleading, finiteness, a, is,
# Nearest to also: ratzenberger, in, wco, muslim, relaunched, nonempty, toby, spalding,
# Nearest to s: tenochtitl, entitled, imagination, quijote, maradona, preoccupations, six, oli,
# Nearest to where: footwork, ellipsoids, woolly, zf, ket, carotenoids, protolanguage, easily,
# Nearest to known: genealogy, twists, jabal, upkeep, second, zloty, established, housemates,
# Nearest to award: awards, nominated, nominations, best, emmy, academy, chicagoans, arrowhead,
# Nearest to versions: nt, divination, cairns, adoptionism, shia, landlines, directx, sod,
# Nearest to ocean: britain, shortwave, intelsat, shoal, kostas, satellite, rico, neva,
# Nearest to question: considered, paradigmatic, grants, subsisting, bold, mlas, esti, consulars,
# Nearest to except: worms, thyme, juicy, synoptic, openings, earthbound, oils, terribly,
# Nearest to troops: army, ironclad, garand, stavropol, rages, forces, civilian, typos,
# Nearest to taking: cosmology, jezebel, alphege, amniocentesis, fdi, invariant, occurs, finalize,
# Nearest to joseph: salzburg, infix, mortar, riflemen, gunshot, misches, bebe, eyewitness,
# Epoch 5/10 Iteration: 21100 Avg. Training loss: 3.9209 0.6405 sec/batch
# Epoch 5/10 Iteration: 21200 Avg. Training loss: 3.9247 0.6083 sec/batch
# Epoch 5/10 Iteration: 21300 Avg. Training loss: 3.8933 0.6174 sec/batch
# Epoch 5/10 Iteration: 21400 Avg. Training loss: 3.9507 0.6572 sec/batch
# Epoch 6/10 Iteration: 23400 Avg. Training loss: 3.8907 0.9526 sec/batch
# Epoch 6/10 Iteration: 23500 Avg. Training loss: 3.8876 0.9638 sec/batch
# Epoch 6/10 Iteration: 23600 Avg. Training loss: 3.8371 0.9742 sec/batch
# Epoch 6/10 Iteration: 23700 Avg. Training loss: 3.8587 0.8959 sec/batch
# Epoch 6/10 Iteration: 23800 Avg. Training loss: 3.7983 0.9333 sec/batch
# Epoch 6/10 Iteration: 23900 Avg. Training loss: 3.8586 0.8787 sec/batch
# Epoch 6/10 Iteration: 24000 Avg. Training loss: 3.9061 0.8731 sec/batch
# Nearest to be: because, provability, superintendence, intervenes, wherever, washed, nemean, dismal,
# Nearest to while: jokingly, spurt, disbelief, diane, actuality, short, chairs, outrageous,
# Nearest to are: is, kata, smarta, racine, other, some, faure, below,
# Nearest to to: the, which, a, with, and, over, is, through,
# Nearest to also: in, muslim, matchbox, nagorno, principals, see, malayalam, oriental,
# Nearest to s: tenochtitl, six, imagination, maradona, quijote, fpss, entitled, netsplit,
# Nearest to where: woolly, ellipsoids, footwork, protolanguage, phi, wesleyan, carotenoids, uf,
# Nearest to known: upkeep, genealogy, established, jabal, underwrite, twists, afzul, latina,
# Nearest to award: awards, nominations, nominated, best, academy, emmy, chicagoans, fervently,
# Nearest to versions: nt, divination, landlines, directx, sod, shia, jmp, colander,
# Nearest to ocean: intelsat, shortwave, britain, kostas, satellite, shoal, arabsat, conglomerates,
# Nearest to question: considered, esti, hump, subsisting, grants, paradigmatic, constrained, commenting,
# Nearest to except: thyme, worms, synoptic, earthbound, manny, oils, terribly, juicy,
# Nearest to troops: army, ironclad, forces, civilian, garand, stavropol, seto, waiting,
# Nearest to taking: cosmology, jezebel, alphege, amniocentesis, cycled, cataclysm, finalize, landry,
# Nearest to joseph: salzburg, mortar, gunshot, infix, riflemen, misches, faith, eyewitness,
# Epoch 6/10 Iteration: 24100 Avg. Training loss: 3.8915 0.7998 sec/batch
# Epoch 6/10 Iteration: 24200 Avg. Training loss: 3.8985 0.7270 sec/batch
# Epoch 6/10 Iteration: 24300 Avg. Training loss: 3.7696 0.7248 sec/batch
# Epoch 6/10 Iteration: 24400 Avg. Training loss: 3.8116 0.7546 sec/batch
# Epoch 6/10 Iteration: 24500 Avg. Training loss: 3.8220 0.7099 sec/batch
# Epoch 6/10 Iteration: 24600 Avg. Training loss: 3.7861 0.7391 sec/batch
# Epoch 6/10 Iteration: 24700 Avg. Training loss: 3.8537 0.7311 sec/batch
# Epoch 6/10 Iteration: 24800 Avg. Training loss: 3.8626 0.9105 sec/batch
# Epoch 6/10 Iteration: 24900 Avg. Training loss: 3.8356 0.7144 sec/batch
# Epoch 6/10 Iteration: 25000 Avg. Training loss: 3.8393 0.7148 sec/batch
# Nearest to be: because, provability, wherever, intervenes, nemean, superintendence, if, that,
# Nearest to while: jokingly, actuality, spurt, given, diane, disbelief, short, chairs,
# Nearest to are: other, smarta, kata, is, some, below, faure, racine,
# Nearest to to: is, which, a, the, of, over, and, labial,
# Nearest to also: in, muslim, nonempty, see, malayalam, matchbox, linker, ratzenberger,
# Nearest to s: tenochtitl, six, imagination, quijote, entitled, maradona, drawl, oli,
# Nearest to where: ellipsoids, footwork, woolly, protolanguage, easily, to, using, uf,
# Nearest to known: upkeep, genealogy, underwrite, jabal, housemates, twists, established, second,
# Nearest to award: awards, nominations, nominated, best, academy, chicagoans, fervently, emmy,
# Nearest to versions: divination, nt, directx, cairns, landlines, sod, shia, colander,
# Nearest to ocean: intelsat, shortwave, britain, kostas, satellite, shoal, arabsat, time,
# Nearest to question: considered, esti, grants, subsisting, paradigmatic, problem, constrained, morea,
# Nearest to except: thyme, worms, juicy, synoptic, earthbound, oils, fucked, wh,
# Nearest to troops: army, forces, ironclad, civilian, stavropol, garand, bravery, devasting,
# Nearest to taking: cosmology, amniocentesis, jezebel, alphege, invariant, cycled, wondering, cataclysm,
# Nearest to joseph: salzburg, infix, gunshot, misches, mortar, riflemen, faith, okedo,
# Epoch 6/10 Iteration: 25100 Avg. Training loss: 3.9094 0.7582 sec/batch
# Epoch 6/10 Iteration: 25200 Avg. Training loss: 3.8627 0.7655 sec/batch
# Epoch 6/10 Iteration: 25300 Avg. Training loss: 3.8412 0.7501 sec/batch
# Epoch 6/10 Iteration: 25400 Avg. Training loss: 3.8765 1.1231 sec/batch
# Epoch 6/10 Iteration: 25500 Avg. Training loss: 3.8319 0.9371 sec/batch
# Epoch 6/10 Iteration: 25600 Avg. Training loss: 3.8303 0.7837 sec/batch
# Epoch 6/10 Iteration: 25700 Avg. Training loss: 3.8891 0.8202 sec/batch
# Epoch 6/10 Iteration: 25800 Avg. Training loss: 3.8463 0.8915 sec/batch
# Epoch 6/10 Iteration: 25900 Avg. Training loss: 3.8377 0.8325 sec/batch
# Epoch 6/10 Iteration: 26000 Avg. Training loss: 3.8959 0.7855 sec/batch
# Nearest to be: because, provability, wherever, intervenes, superintendence, nemean, electrostatics, it,
# Nearest to while: jokingly, actuality, disbelief, short, diane, chairs, spurt, given,
# Nearest to are: smarta, kata, other, is, faure, racine, below, taxa,
# Nearest to to: which, the, is, of, over, a, labial, and,
# Nearest to also: in, see, muslim, matchbox, malayalam, nonempty, nagorno, oriental,
# Nearest to s: tenochtitl, the, imagination, six, oli, quijote, entitled, drawl,
# Nearest to where: woolly, ellipsoids, footwork, protolanguage, wesleyan, uf, easily, leftover,
# Nearest to known: upkeep, jabal, established, genealogy, second, twists, zloty, king,
# Nearest to award: awards, nominations, nominated, best, academy, emmy, chicagoans, fervently,
# Nearest to versions: divination, nt, directx, cairns, landlines, sod, colander, mauser,
# Nearest to ocean: intelsat, shortwave, britain, kostas, satellite, time, shoal, eutelsat,
# ...
# Epoch 8/10 Iteration: 36500 Avg. Training loss: 3.7472 1.7308 sec/batch
# Epoch 8/10 Iteration: 36600 Avg. Training loss: 3.7426 2.4169 sec/batch
# Epoch 8/10 Iteration: 36800 Avg. Training loss: 3.7856 2.1101 sec/batch
# Epoch 8/10 Iteration: 36900 Avg. Training loss: 3.7624 1.3071 sec/batch
# Epoch 9/10 Iteration: 37400 Avg. Training loss: 3.7725 0.9566 sec/batch
# Epoch 9/10 Iteration: 37500 Avg. Training loss: 3.7155 1.5759 sec/batch
# Epoch 9/10 Iteration: 37600 Avg. Training loss: 3.7372 0.9323 sec/batch
# Epoch 9/10 Iteration: 37700 Avg. Training loss: 3.6901 0.8644 sec/batch
# Epoch 9/10 Iteration: 37800 Avg. Training loss: 3.7579 0.8881 sec/batch
# Epoch 9/10 Iteration: 37900 Avg. Training loss: 3.7844 0.8316 sec/batch
# Epoch 9/10 Iteration: 38000 Avg. Training loss: 3.7576 1.4555 sec/batch
# Nearest to be: because, this, it, then, see, that, to, a,
# Nearest to while: short, jokingly, disbelief, judogi, feel, diane, unmasked, queue,
# Nearest to are: is, other, there, some, these, kata, each, such,
# Nearest to to: the, a, and, with, which, of, this, as,
# Nearest to also: in, the, see, as, of, to, and, is,
# Nearest to s: the, of, six, to, was, zero, its, in,
# Nearest to where: in, to, phi, alto, woolly, he, with, protolanguage,
# Nearest to known: the, upkeep, afzul, from, established, housemates, many, see,
# Nearest to award: awards, best, nominations, nominated, academy, emmy, achievements, oscars,
# Nearest to versions: nt, divination, version, sod, directx, landlines, kamal, colander,
# Nearest to ocean: intelsat, shortwave, shoal, eutelsat, kostas, britain, arithm, arabsat,
# Nearest to question: considered, hump, consulars, carr, constrained, acceptable, morea, esti,
# Nearest to except: earthbound, thyme, only, manny, all, straits, synoptic, bateman,
# Nearest to troops: army, bravery, stavropol, ironclad, eno, forces, waiting, neophyte,
# Nearest to taking: cosmology, jezebel, cycled, landry, cataclysm, alphege, extended, wondering,
# Nearest to joseph: flowered, gunshot, mortar, tiered, misches, okedo, commitment, hhs,
# Epoch 9/10 Iteration: 38100 Avg. Training loss: 3.8045 1.4935 sec/batch
# Epoch 9/10 Iteration: 38400 Avg. Training loss: 3.6945 1.0615 sec/batch
# Epoch 9/10 Iteration: 38500 Avg. Training loss: 3.7331 1.2257 sec/batch
# Epoch 9/10 Iteration: 38600 Avg. Training loss: 3.7616 0.9330 sec/batch
# Epoch 9/10 Iteration: 38700 Avg. Training loss: 3.7445 1.0263 sec/batch
# Epoch 9/10 Iteration: 38800 Avg. Training loss: 3.7549 0.9942 sec/batch
# Epoch 9/10 Iteration: 38900 Avg. Training loss: 3.7782 1.0355 sec/batch
# Epoch 9/10 Iteration: 39000 Avg. Training loss: 3.8239 0.9887 sec/batch
# Nearest to be: because, this, a, then, it, that, see, to,
# Nearest to while: short, jokingly, disbelief, given, actuality, feel, judogi, diane,
# Nearest to are: is, other, some, these, of, there, such, the,
# Nearest to to: the, a, and, as, of, which, in, with,
# Nearest to also: in, the, and, of, see, as, is, other,
# Nearest to s: the, of, six, to, zero, eight, its, by,
# Nearest to where: alto, in, to, this, phi, woolly, protolanguage, ellipsoids,
# Nearest to known: the, housemates, upkeep, from, called, see, haywood, in,
# Nearest to award: awards, best, nominated, nominations, academy, emmy, oscars, achievements,
# Nearest to versions: nt, divination, directx, landlines, kamal, sod, version, colander,
# Nearest to ocean: intelsat, shoal, shortwave, eutelsat, kostas, earth, arithm, arabsat,
# Nearest to question: considered, problem, consulars, constrained, carr, hump, acceptable, esti,
# Nearest to except: only, thyme, earthbound, all, as, manny, fanfiction, straits,
# Nearest to troops: army, bravery, stavropol, eno, forces, ironclad, waiting, xhtml,
# Nearest to taking: cosmology, jezebel, landry, cycled, alphege, cataclysm, extended, mapuche,
# Nearest to joseph: flowered, gunshot, misches, tiered, commitment, hhs, hillsides, mortar,
# Epoch 9/10 Iteration: 39200 Avg. Training loss: 3.7724 1.1014 sec/batch
# Epoch 9/10 Iteration: 39300 Avg. Training loss: 3.7459 1.3752 sec/batch
# Epoch 9/10 Iteration: 39400 Avg. Training loss: 3.7442 0.8968 sec/batch
# Epoch 9/10 Iteration: 39500 Avg. Training loss: 3.7344 0.9117 sec/batch
# Epoch 9/10 Iteration: 39600 Avg. Training loss: 3.7830 0.8890 sec/batch
# Epoch 9/10 Iteration: 39700 Avg. Training loss: 3.7772 0.7740 sec/batch
# Epoch 9/10 Iteration: 39800 Avg. Training loss: 3.7437 0.7185 sec/batch
# Epoch 9/10 Iteration: 39900 Avg. Training loss: 3.8042 0.7143 sec/batch
# Epoch 9/10 Iteration: 40000 Avg. Training loss: 3.7555 0.7995 sec/batch
# Nearest to be: because, this, that, it, see, a, is, to,
# Nearest to while: short, feel, disbelief, jokingly, judogi, actuality, diane, given,
# Nearest to are: other, is, some, there, these, such, which, all,
# Nearest to to: the, and, of, as, a, with, this, which,
# Nearest to also: in, and, the, of, see, to, as, other,
# Nearest to s: the, of, six, to, by, eight, was, in,
# Nearest to where: in, this, alto, phi, woolly, with, protolanguage, intercultural,
# Nearest to known: the, from, upkeep, established, of, king, in, housemates,
# Nearest to award: awards, best, nominated, nominations, academy, emmy, oscars, razzie,
# Nearest to versions: nt, divination, directx, tabbed, landlines, colander, kamal, sod,
# Nearest to ocean: intelsat, shoal, eutelsat, shortwave, kostas, arithm, luba, earth,
# Nearest to question: considered, consulars, constrained, carr, acceptable, hump, esti, mlas,
# Nearest to except: only, earthbound, thyme, as, all, straits, fanfiction, manny,
# Nearest to troops: army, bravery, stavropol, forces, xhtml, eno, ironclad, waiting,
# Nearest to taking: cosmology, jezebel, landry, extended, cycled, alphege, cataclysm, mapuche,
# Nearest to joseph: flowered, misches, gunshot, tiered, commitment, mortar, hillsides, savigny,
# Epoch 9/10 Iteration: 40100 Avg. Training loss: 3.7637 0.7431 sec/batch
# Epoch 9/10 Iteration: 40200 Avg. Training loss: 3.7549 1.6357 sec/batch
# Epoch 9/10 Iteration: 40300 Avg. Training loss: 3.7403 1.2678 sec/batch
# Epoch 9/10 Iteration: 40400 Avg. Training loss: 3.7207 1.1963 sec/batch
# Epoch 9/10 Iteration: 40500 Avg. Training loss: 3.8379 1.0534 sec/batch
# Epoch 9/10 Iteration: 40600 Avg. Training loss: 3.7797 0.9709 sec/batch
# Epoch 9/10 Iteration: 40700 Avg. Training loss: 3.8812 0.8881 sec/batch
# Epoch 9/10 Iteration: 40800 Avg. Training loss: 3.7768 0.9337 sec/batch
# Epoch 9/10 Iteration: 40900 Avg. Training loss: 3.8188 0.9708 sec/batch
# Epoch 9/10 Iteration: 41000 Avg. Training loss: 3.7248 0.8250 sec/batch
# Nearest to be: because, this, it, see, a, provability, that, to,
# Nearest to while: short, disbelief, feel, judogi, curriculum, actuality, jokingly, majority,
# Nearest to are: other, is, some, there, these, or, which, such,
# Nearest to to: the, a, and, as, of, this, with, in,
# Nearest to also: in, see, the, and, of, include, is, other,
# Nearest to s: the, of, six, by, to, zero, a, eight,
# Nearest to where: in, woolly, this, with, phi, to, he, protolanguage,
# Nearest to known: upkeep, from, haywood, housemates, established, the, king, genealogy,
# Nearest to award: awards, best, nominations, nominated, academy, emmy, oscars, chicagoans,
# Nearest to versions: nt, divination, tabbed, directx, landlines, colander, kamal, pointer,
# Nearest to ocean: intelsat, eutelsat, shoal, arithm, shortwave, kostas, britain, luba,
# Nearest to question: considered, constrained, consulars, acceptable, hump, esti, mlas, carr,
# Nearest to except: only, earthbound, thyme, as, all, synoptic, oils, realigned,
# Nearest to troops: army, bravery, stavropol, xhtml, eno, rebellions, forces, waiting,
# Nearest to taking: cosmology, jezebel, extended, cycled, landry, alphege, cataclysm, mapuche,
# Nearest to joseph: tiered, misches, flowered, gunshot, okedo, phoenix, mortar, maw,
# Epoch 9/10 Iteration: 41100 Avg. Training loss: 3.6907 0.8216 sec/batch
# Epoch 9/10 Iteration: 41200 Avg. Training loss: 3.7600 0.9473 sec/batch
# Epoch 9/10 Iteration: 41300 Avg. Training loss: 3.6908 0.9299 sec/batch
# Epoch 9/10 Iteration: 41400 Avg. Training loss: 3.7923 0.8238 sec/batch
# Epoch 9/10 Iteration: 41500 Avg. Training loss: 3.7462 0.7423 sec/batch
# Epoch 9/10 Iteration: 41600 Avg. Training loss: 3.7642 0.6943 sec/batch
# Epoch 10/10 Iteration: 41700 Avg. Training loss: 3.7960 0.4565 sec/batch
# Epoch 10/10 Iteration: 41800 Avg. Training loss: 3.7303 0.8106 sec/batch
# Epoch 10/10 Iteration: 41900 Avg. Training loss: 3.7555 0.9318 sec/batch
# Epoch 10/10 Iteration: 42000 Avg. Training loss: 3.7576 0.9379 sec/batch
# Nearest to be: because, this, to, it, that, see, a, then,
# Nearest to while: short, disbelief, judogi, feel, into, diane, vasa, schemata,
# Nearest to are: other, there, some, is, these, such, of, and,
# Nearest to to: the, a, and, of, in, this, as, from,
# Nearest to also: in, the, see, of, to, and, is, as,
# Nearest to s: the, of, six, by, in, to, was, a,
# Nearest to where: in, with, to, he, woolly, this, phi, protolanguage,
# Nearest to known: the, from, established, upkeep, called, see, housemates, haywood,
# Nearest to award: awards, best, nominations, nominated, academy, oscars, emmy, razzie,
# Nearest to versions: nt, divination, directx, tabbed, landlines, version, kamal, pointer,
# Nearest to ocean: intelsat, shoal, eutelsat, shortwave, earth, luba, arithm, kostas,
# Nearest to question: considered, constrained, consulars, esti, morea, hump, acceptable, mlas,
# Nearest to except: only, earthbound, thyme, bateman, as, synoptic, straits, analogous,
# Nearest to troops: army, bravery, stavropol, xhtml, soldiers, waiting, ironclad, rebellions,
# Nearest to taking: cosmology, jezebel, landry, cycled, alphege, extended, cataclysm, wondering,
# Nearest to joseph: flowered, misches, gunshot, phoenix, tiered, okedo, cooper, nikolaus,
# Epoch 10/10 Iteration: 42100 Avg. Training loss: 3.7005 1.0008 sec/batch
# Epoch 10/10 Iteration: 42200 Avg. Training loss: 3.7234 0.6995 sec/batch
# Epoch 10/10 Iteration: 42300 Avg. Training loss: 3.7209 0.8349 sec/batch
# Epoch 10/10 Iteration: 42400 Avg. Training loss: 3.7179 0.7031 sec/batch
# Epoch 10/10 Iteration: 42500 Avg. Training loss: 3.7761 2.0688 sec/batch
# Epoch 10/10 Iteration: 42700 Avg. Training loss: 3.7834 1.4401 sec/batch
# Epoch 10/10 Iteration: 42800 Avg. Training loss: 3.6667 2.0755 sec/batch
# Epoch 10/10 Iteration: 42900 Avg. Training loss: 3.7278 1.2396 sec/batch
# Epoch 10/10 Iteration: 43000 Avg. Training loss: 3.6760 1.0548 sec/batch
# Nearest to be: this, because, to, it, that, a, if, is,
# Nearest to while: short, for, into, disbelief, judogi, actuality, diane, queue,
# Nearest to are: other, is, the, some, of, there, and, such,
# Nearest to to: the, and, a, of, this, as, in, which,
# Nearest to also: in, the, and, of, is, see, to, as,
# Nearest to s: the, of, six, its, to, by, zero, eight,
# Nearest to where: in, with, woolly, this, to, phi, alto, protolanguage,
# Nearest to known: the, from, in, see, is, called, housemates, although,
# Nearest to award: awards, best, nominations, academy, nominated, oscars, emmy, achievements,
# Nearest to versions: divination, nt, version, kamal, tabbed, directx, pointer, sod,
# Nearest to ocean: intelsat, shoal, eutelsat, shortwave, earth, arithm, kostas, luba,
# Nearest to question: considered, constrained, problem, esti, consulars, mlas, universalis, whether,
# Nearest to except: only, earthbound, thyme, as, synoptic, all, analogous, fanfiction,
# Nearest to troops: army, bravery, soldiers, xhtml, stavropol, forces, eno, rebellions,
# Nearest to taking: cosmology, jezebel, alphege, landry, cataclysm, extended, cycled, mapuche,
# Nearest to joseph: flowered, misches, latter, tiered, gunshot, okedo, phoenix, savigny,
# Epoch 10/10 Iteration: 43100 Avg. Training loss: 3.6710 1.0502 sec/batch
# Epoch 10/10 Iteration: 43200 Avg. Training loss: 3.7031 0.7345 sec/batch
# Epoch 10/10 Iteration: 43300 Avg. Training loss: 3.7482 0.6962 sec/batch
# Epoch 10/10 Iteration: 43400 Avg. Training loss: 3.7278 0.7258 sec/batch
# Epoch 10/10 Iteration: 43500 Avg. Training loss: 3.7429 0.7045 sec/batch
# Epoch 10/10 Iteration: 43600 Avg. Training loss: 3.7863 0.6702 sec/batch
# Epoch 10/10 Iteration: 43700 Avg. Training loss: 3.7849 0.6938 sec/batch
# Epoch 10/10 Iteration: 43800 Avg. Training loss: 3.7163 0.7087 sec/batch
# Epoch 10/10 Iteration: 43900 Avg. Training loss: 3.7268 0.9070 sec/batch
# Epoch 10/10 Iteration: 44000 Avg. Training loss: 3.7311 1.0211 sec/batch
# Nearest to be: because, this, it, that, to, then, is, a,
# Nearest to while: short, queue, disbelief, actuality, feel, judogi, for, register,
# Nearest to are: other, these, of, some, is, the, all, there,
# Nearest to to: the, a, and, with, of, this, is, as,
# Nearest to also: in, the, of, see, and, is, as, to,
# Nearest to s: the, of, six, by, a, to, in, eight,
# Nearest to where: in, this, alto, with, woolly, easily, to, phi,
# Nearest to known: the, from, although, see, is, called, of, housemates,
# Nearest to award: awards, best, academy, nominations, nominated, oscars, achievements, chicagoans,
# Nearest to versions: divination, nt, directx, tabbed, version, kamal, landlines, pointer,
# Nearest to ocean: intelsat, eutelsat, shoal, earth, shortwave, luba, arithm, relent,
# Nearest to question: considered, constrained, problem, universalis, consulars, hump, esti, cabbie,
# Nearest to except: only, earthbound, all, thyme, as, analogous, synoptic, fanfiction,
# Nearest to troops: army, bravery, soldiers, stavropol, eno, rebellions, forces, neophyte,
# Nearest to taking: cosmology, jezebel, alphege, extended, cycled, landry, cataclysm, mapuche,
# Nearest to joseph: misches, flowered, tiered, phoenix, okedo, savigny, gunshot, hillsides,
# Epoch 10/10 Iteration: 44100 Avg. Training loss: 3.7828 0.7956 sec/batch
# Epoch 10/10 Iteration: 44200 Avg. Training loss: 3.7500 0.7435 sec/batch
# Epoch 10/10 Iteration: 44300 Avg. Training loss: 3.7452 0.9121 sec/batch
# Epoch 10/10 Iteration: 44400 Avg. Training loss: 3.7596 0.9381 sec/batch
# Epoch 10/10 Iteration: 44500 Avg. Training loss: 3.7835 1.3607 sec/batch
# Epoch 10/10 Iteration: 44600 Avg. Training loss: 3.7610 0.8578 sec/batch
# Epoch 10/10 Iteration: 44700 Avg. Training loss: 3.7457 1.1267 sec/batch
# Epoch 10/10 Iteration: 44800 Avg. Training loss: 3.7505 2.2849 sec/batch
# Epoch 10/10 Iteration: 44900 Avg. Training loss: 3.7265 1.2395 sec/batch
# Epoch 10/10 Iteration: 45000 Avg. Training loss: 3.7285 1.0349 sec/batch
# Nearest to be: it, this, because, that, to, is, other, for,
# Nearest to while: short, for, queue, actuality, into, feel, plasmid, and,
# Nearest to are: other, is, some, these, all, of, the, and,
# Nearest to to: the, and, of, a, this, as, is, with,
# Nearest to also: in, the, see, of, and, to, other, is,
# Nearest to s: the, six, of, by, to, eight, as, a,
# Nearest to where: in, this, with, woolly, to, alto, protolanguage, he,
# Nearest to known: the, of, from, in, although, see, established, is,
# Nearest to award: awards, best, academy, nominated, nominations, oscars, emmy, achievement,
# Nearest to versions: nt, divination, tabbed, directx, version, landlines, pointer, kamal,
# Nearest to ocean: intelsat, eutelsat, shoal, shortwave, arithm, jenkins, earth, relent,
# Nearest to question: considered, constrained, problem, consulars, esti, overrides, hump, cabbie,
# Nearest to except: only, earthbound, all, synoptic, as, thyme, realigned, bateman,
# Nearest to troops: army, bravery, soldiers, rebellions, forces, waiting, stavropol, xhtml,
# Nearest to taking: cosmology, jezebel, alphege, cycled, landry, extended, cataclysm, mapuche,
# Nearest to joseph: tiered, flowered, misches, okedo, phoenix, savigny, gunshot, hillsides,
# Epoch 10/10 Iteration: 45100 Avg. Training loss: 3.7522 0.9492 sec/batch
# Epoch 10/10 Iteration: 45200 Avg. Training loss: 3.7621 0.9267 sec/batch
# Epoch 10/10 Iteration: 45300 Avg. Training loss: 3.8528 1.0285 sec/batch
# Epoch 10/10 Iteration: 45400 Avg. Training loss: 3.8153 1.1867 sec/batch
# Epoch 10/10 Iteration: 45500 Avg. Training loss: 3.7941 0.9574 sec/batch
# Epoch 10/10 Iteration: 45600 Avg. Training loss: 3.7752 0.9906 sec/batch
# Epoch 10/10 Iteration: 45700 Avg. Training loss: 3.6344 1.0832 sec/batch
# Epoch 10/10 Iteration: 45800 Avg. Training loss: 3.7184 0.9534 sec/batch

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
